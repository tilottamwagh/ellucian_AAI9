# %% [markdown]
# # Build a Travily and Invoke Gen AI with Bedrock Chatbot

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_openai langchain_core langgraph langgraph-prebuilt langchain-tavily
# %pip install boto3
# %pip install --upgrade python-dotenv

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

os.environ["AWS_ACCESS_KEY_ID"] = os.getenv('AWS_ACCESS_KEY_ID')
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv('AWS_SECRET_ACCESS_KEY')
os.environ["AWS_DEFAULT_REGION"] =os.getenv('AWS_DEFAULT_REGION')
os.environ["TAVILY_API_KEY"] = os.getenv('TAVILY_API_KEY')
# os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %%
os.environ["LANGSMITH_API_KEY"] = os.getenv('LANGSMITH_API_KEY')
os.environ["LANGSMITH_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "tutorial"

# %% [markdown]
# ## Define the tool
#
# Define the web search tool:

# %%
from langchain_tavily import TavilySearch

search_tool = TavilySearch(max_results=2)

# %% [markdown]
# # Define the tool use AWS API Gateway endpoint

# %%
from langchain_core.tools import tool

tools = [search_tool]
search_tool.invoke("What's a 'node' in LangGraph?")
# Out:
# {'query': "What's a 'node' in LangGraph?",
#  'response_time': 0.83,
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.linkedin.com/pulse/langgraph-nodes-agents-multi-agent-composition-walid-negm-kaxwe',
#    'title': '🧠 LangGraph — Nodes, Agents, and Multi- ...',
#    'content': 'LangGraph is agnostic to node content: a node is simply a callable (function or class) that consumes and updates graph state. Whether a node is',
#    'score': 0.8548001,
#    'raw_content': None},
#   {'url': 'https://dev.to/raunaklallala/understanding-core-concepts-of-langgraph-deep-dive-1d7h',
#    'title': 'Understanding Core Concepts of LangGraph (Deep Dive)',
#    'content': 'At the core, LangGraph has three simple but powerful building blocks: **Nodes, Edges, and State**. Each of those is a *Node*. In LangGraph, a Node can be many things:. Each Node is like a worker with a simple contract: it takes an input, does its piece of the job, and pushes out an output. **Analogy:** Nodes are like “stations” on a metro map. **Analogy:** If Nodes are stations, Edges are the railway tracks. * Shared state → memory that’s accessible to *all* nodes during execution. * **Node 1:** Input Capture → User enters “Hello World.”. * Edges: If skills gap detected → route to skill-gap explainer node. Once you start thinking in terms of Nodes, Edges, and State, you realize this is less about AI “chats” and more about *AI workflows*. This trio (Nodes, Edges, State) is why LangGraph isn’t just a library, but a framework for *persistent, adaptive, multi-step systems* you can actually trust.',
#    'score': 0.8437023,
#    'raw_content': None}],
#  'request_id': '5f76562d-d195-43ab-b009-dacb4a9bb28d'}

# %% [markdown]
# ## Define the graph

# %%
from langchain_aws import ChatBedrock

llm = ChatBedrock(
   model_id="amazon.nova-lite-v1:0",
   temperature=1,
)

# %% [markdown]
# We can now incorporate it into a StateGraph:

# %%
from typing import Annotated

from langgraph.prebuilt import ToolNode, tools_condition
from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from IPython.display import Image, display

class State(TypedDict):
    messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools))

graph_builder.add_edge(START, "chatbot")
graph_builder.add_conditional_edges("chatbot", tools_condition)
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge("chatbot", END)

graph = graph_builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langchain_core.messages import AIMessage, HumanMessage
result= graph.invoke({"messages": [HumanMessage(content="what is the current weather in bangalore?")]})

# %%
result
# Out:
# {'messages': [HumanMessage(content='what is the current weather in bangalore?', additional_kwargs={}, response_metadata={}, id='272d653b-36ea-4b2d-80b0-6680e198ecc1'),
#   AIMessage(content=[{'type': 'text', 'text': "<thinking>The User wants to know the current weather in Bangalore. As I don't have real-time data access, I need to use the Tavily search tool to get the latest information.</thinking>\n"}, {'type': 'tool_use', 'name': 'tavily_search', 'input': {'time_range': 'day', 'query': 'current weather in Bangalore'}, 'id': 'tooluse_f0bjFU91h1nLa3bhg8LJSz'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '27ecebea-e240-4ca5-ae2f-33e22cba18e2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 13 Mar 2026 08:19:53 GMT', 'content-type': 'application/json', 'content-length': '542', 'connection': 'keep-alive', 'x-amzn-requestid': '27ecebea-e240-4ca5-ae2f-33e22cba18e2'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [727]}, 'model_provider': 'bedrock_converse', 'model_name': 'amazon.nova-lite-v1:0'}, id='lc_run--019ce647-d15b-7353-b228-14300a1177e0-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'current weather in Bangalore'}, 'id': 'tooluse_f0bjFU91h1nLa3bhg8LJSz', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2047, 'output_tokens': 70, 'total_tokens': 2117, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content='{"query": "current weather in Bangalore", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Bangalore", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Bangalore\', \'region\': \'Karnataka\', \'country\': \'India\', \'lat\': 12.9833, \'lon\': 77.5833, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1773389981, \'localtime\': \'2026-03-13 13:49\'}, \'current\': {\'last_updated_epoch\': 1773389700, \'last_updated\': \'2026-03-13 13:45\', \'temp_c\': 32.2, \'temp_f\': 90.0, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 11.9, \'wind_kph\': 19.1, \'wind_degree\': 99, \'wind_dir\': \'E\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 28, \'cloud\': 25, \'feelslike_c\': 30.0, \'feelslike_f\': 86.0, \'windchill_c\': 33.5, \'windchill_f\': 92.2, \'heatindex_c\': 31.4, \'heatindex_f\': 88.5, \'dewpoint_c\': 1.9, \'dewpoint_f\': 35.3, \'vis_km\': 6.0, \'vis_miles\': 3.0, \'uv\': 11.2, \'gust_mph\': 13.6, \'gust_kph\': 22.0}}", "score": 0.9997896, "raw_content": null}, {"url": "https://www.skymetweather.com/forecast/weather/india/karnataka/bangalore%20urban/bangalore%20north/fifteen-days-forecast", "title": "Extended or 15 days weather forecast for Bangalore North Karnataka", "content": "Bangalore North. Bangalore Urban. Clear Sky. 17°C. Current temperature. 6:45 AM, Mar 13, 2026. Rain probability. 0 %. Hourly. 7 Days. 15 Days. Weather buddy.", "score": 0.9997154, "raw_content": null}], "response_time": 1.35, "request_id": "03755907-f9cf-4000-92ba-ef213698e79b"}', name='tavily_search', id='d0996053-9fb2-4b34-a253-efeebbe828f0', tool_call_id='tooluse_f0bjFU91h1nLa3bhg8LJSz'),
#   AIMessage(content=[{'type': 'text', 'text': "<thinking>I've found relevant data regarding the current weather in Bangalore. The most recent result from the search engine shows the weather in Bangalore as sunny with a temperature of 32.2°C (90.0°F).</thinking>\n\n"}, {'type': 'tool_use', 'name': 'tavily_search', 'input': {'time_range': 'day', 'query': 'current weather in Bangalore'}, 'id': 'tooluse_rM44NGWgjdfQjK2AiSLYpF'}, {'type': 'text', 'text': '\n\nBased on the search results, the current weather in Bangalore is sunny with a temperature of 32.2°C (90.0°F). The weather data was last updated at 13:45 on 2026-03-13. \n\n<thinking>The search engine result indicates the temperature and weather condition. There is no further information available from the results regarding humidity, wind speed, or other details. If the User needs more detailed information, I could suggest a different search term or website for a more comprehensive weather report.</thinking>'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'dd8beda1-ebb9-4e4d-b1e5-70b8d8fc04de', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 13 Mar 2026 08:19:57 GMT', 'content-type': 'application/json', 'content-length': '1108', 'connection': 'keep-alive', 'x-amzn-requestid': 'dd8beda1-ebb9-4e4d-b1e5-70b8d8fc04de'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [1661]}, 'model_provider': 'bedrock_converse', 'model_name': 'amazon.nova-lite-v1:0'}, id='lc_run--019ce647-dd29-7e90-8138-14c5551ba049-0', tool_calls=[{'name': 'tavily_search', 'args': {'time_range': 'day', 'query': 'current weather in Bangalore'}, 'id': 'tooluse_rM44NGWgjdfQjK2AiSLYpF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2939, 'output_tokens': 197, 'total_tokens': 3136, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content='{"query": "current weather in Bangalore", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Bangalore", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Bangalore\', \'region\': \'Karnataka\', \'country\': \'India\', \'lat\': 12.9833, \'lon\': 77.5833, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1773389981, \'localtime\': \'2026-03-13 13:49\'}, \'current\': {\'last_updated_epoch\': 1773389700, \'last_updated\': \'2026-03-13 13:45\', \'temp_c\': 32.2, \'temp_f\': 90.0, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 11.9, \'wind_kph\': 19.1, \'wind_degree\': 99, \'wind_dir\': \'E\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 28, \'cloud\': 25, \'feelslike_c\': 30.0, \'feelslike_f\': 86.0, \'windchill_c\': 33.5, \'windchill_f\': 92.2, \'heatindex_c\': 31.4, \'heatindex_f\': 88.5, \'dewpoint_c\': 1.9, \'dewpoint_f\': 35.3, \'vis_km\': 6.0, \'vis_miles\': 3.0, \'uv\': 11.2, \'gust_mph\': 13.6, \'gust_kph\': 22.0}}", "score": 0.9151043, "raw_content": null}, {"url": "https://indianexpress.com/section/weather/kolar-weather-forecast-today/", "title": "Kolar Weather Today: Live Temperature, Hourly Forecast Updates", "content": "Current Weather March 13, 2026. Partly cloudy. 21.2°C. Partly cloudy Feels like ... Bangalore, 23.2°C. Clear. 65%, 0, 15.5 kmph / E. Mysore, 21.7°C.", "score": 0.90692574, "raw_content": null}], "response_time": 1.67, "request_id": "5e321081-53f6-4250-8a4d-324f3cc1191b"}', name='tavily_search', id='4899eb9c-23eb-4eae-bb75-6c2c78f22a4d', tool_call_id='tooluse_rM44NGWgjdfQjK2AiSLYpF'),
#   AIMessage(content="<thinking>Upon receiving the latest result from the search engine, I can confirm the weather condition in Bangalore. The result shows the current weather in Bangalore as sunny with a temperature of 32.2°C (90.0°F). It's important to note that this is just a small snippet of the data provided by the search engine. I can share more information if the User is interested.</thinking> Based on the latest search results, the current weather in Bangalore is sunny with a temperature of 32.2°C (90.0°F). The weather data was last updated at 13:45 on 2026-03-13. Would you like more detailed information?", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'f8005447-1c86-4adf-b4f3-a80ed13bec9f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 13 Mar 2026 08:20:01 GMT', 'content-type': 'application/json', 'content-length': '810', 'connection': 'keep-alive', 'x-amzn-requestid': 'f8005447-1c86-4adf-b4f3-a80ed13bec9f'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [1339]}, 'model_provider': 'bedrock_converse', 'model_name': 'amazon.nova-lite-v1:0'}, id='lc_run--019ce647-edad-75e2-aeef-d055d619ba82-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3946, 'output_tokens': 152, 'total_tokens': 4098, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})]}
